# %% [markdown]
# ## Listas

# %%
# Criando uma lista
listadomercado = ["ovos", "farinha", "leite", "maças"]

# %%
# Imprimindo a lista
print(listadomercado[2])
# Out:
# leite

# %%
# Criando outra lista
listadomercado2 = ["ovos", "farinha", "leite", "maças"]

# %%
# Imprimindo a lista
print(listadomercado2)
# Out:
# ['ovos', 'farinha', 'leite', 'maças']

# %%
# Criando lista
lista3 = [12, 100, "Universidade nota 100", '2020', 2020]

# %%
# Imprimindo
print(lista3)
# Out:
# [12, 100, 'Universidade nota 100', '2020', 2020]

# %%
lista3.append([122, 200, "Facudade"])

# %%
print(lista3)
# Out:
# [12, 100, 'Universidade nota 100', '2020', 2020, [122, 200, 'Facudade']]

# %%
# Atribuindo cada valor da lista a uma variável.
item1 = lista3[0]
item2 = lista3[1]
item3 = lista3[2]
item4 = lista3[5][1]

# %%
item4
# Out:
# 200

# %%
item5 = lista3[4]

# %%
print(item4)
# Out:
# 200

# %%
item4 = lista3[4]
item4
# Out:
# 2020

# %%
# Imprimindo as variáveis
print(item1, item2, item3)
# Out:
# 12 100 Universidade nota 100

# %% [markdown]
# ### Atualizando um item da lista

# %%
# Imprimindo um item da lista
listadomercado2[2]
# Out:
# 'leite'

# %%
# Atualizando um item da lista
listadomercado2[2] = "chocolate"

# %%
# Imprimindo lista alterada
listadomercado2

# %% [markdown]
# ### Deletando um item da lista

# %%
listadomercado2 = ["ovos", "farinha", "leite", "maças"]

# %%
# Out of index. Não é possível deletar um item que não existe na lista
del listadomercado2[1]

# %%
# Imprimindo o item com a lista alterada
listadomercado2
# Out:
# ['ovos', 'leite', 'maças']

# %% [markdown]
# ### Listas de listas (Listas aninhadas)
# Listas de listas são matrizes em Python

# %%
# Criando uma lista de listas
listas = [[1,2,3], [20,15,14], [10.1,8.7,2.3]]

# %%
# Imprimindo a lista
listas[1][1]
# Out:
# 15

# %%
# Atribuindo um item da lista a uma variável
a = listas[0]

# %%
a
# Out:
# [1, 2, 3]

# %%
b = a[0]

# %%
b

# %%
list1 = listas[1]

# %%
list1

# %%
valor10 = list1[0]

# %%
valor_1_0_1

# %%
valor_1_2 = list1[2]

# %%
valor_1_2

# %%
list2 = listas[2]

# %%
list2

# %%
valor_2_0 = list2[0]

# %%
valor_2_0

# %% [markdown]
# ### Operações com listas

# %%
# Criando uma lista aninhada (lista de listas)
listas = [[1,2,3], [10,15,14], [10.1,8.7,2.3]]

# %%
listas

# %%
# Atribuindo à variável a, o primeiro valor da primeira lista
a = listas[2][0]

# %%
a

# %%
b = listas[1][2]

# %%
b

# %%
listas

# %%
c = d * listas[2][0]

# %%
e

# %% [markdown]
# ### Concatenando listas

# %%
lista_s1 = [34, 32, 56]

# %%
lista_s1

# %%
lista_s2 = [21, 90, 51]

# %%
lista_s2

# %%
# Concatenando listas
lista_total = lista_s1 + lista_s2

# %%
lista_total

# %% [markdown]
# ## Operador in

# %%
# Criando uma lista
lista_teste_op = [100, 2, -5, 3.4]

# %%
# Verificando se o valor 10 pertence a lista
print(10 in lista_teste_op)
# Out:
# False

# %%
# Verificando se o valor 100 pertence a lista
print(100 in lista_teste_op)
# Out:
# True

# %% [markdown]
# ## Funções Built-in

# %%
# Função len() retorna o comprimento da lista
len(lista_teste_op)
# Out:
# 4

# %%
# Função max() retorna o valor máximo da lista
max(lista_teste_op)
# Out:
# 100

# %%
# Função min() retorna o valor mínimo da lista
min(lista_teste_op)
# Out:
# -5

# %%
# Criando uma lista
listadomercado2 = ["ovos", "farinha", "leite", "maças"]

# %%
# Adicionando um item à lista
listadomercado2.append("carne")

# %%
listadomercado2
# Out:
# ['ovos', 'farinha', 'leite', 'maças', 'carne']

# %%
listadomercado2.append("carne")

# %%
listadomercado2
# Out:
# ['ovos', 'farinha', 'leite', 'maças', 'carne', 'carne']

# %%
listadomercado2.count("carne")

# %%
len(listadomercado2)

# %%
len('Daniel')

# %%
# Criando uma lista vazia
a = []

# %%
print(a)
# Out:
# []

# %%
type(a)
# Out:
# list

# %%
a.append(10)

# %%
a
# Out:
# [10]

# %%
a.append(50)

# %%
a

# %%
old_list = [1,2,5,10,20]
old_list

# %%
new_list = []

# %%
old_list

# %%
# Copiando os itens de uma lista para outra
for item in old_list:
    print(item)
    new_list.append(item)

print(new_list)

# %%
new_list

# %%
c = [20,30]

# %%
c.append(60)

# %%
c.append(20)

# %%
c

# %%
c.count(60)

# %%
cidades =[]

# %%
cidades = ['Recife', 'Manaus', 'Salvador']
cidades.extend(['Fortaleza', 'Palmas'])
print (cidades)

# %%
cidades = ['Recife', 'Manaus', 'Salvador']
cidades.append(['Fortaleza', 'Palmas'])
print (cidades)

# %%
cidades.index('Salvador')

# %% [markdown]
# Lembre-se: em Python o índice começa por 0!

# %%
cidades.index('Rio de Janeiro')

# %%
cidades

# %%
del cidades[2]

# %%
cidades

# %%
# Remove um item da lista
cidades.remove('Manaus')

# %%
cidades

# %%
# Reverte a lista
cidades.reverse()

# %%
# Imprime a lista
cidades

# %%
x = [3, 4, 2, 1]

# %%
x

# %%
# Ordena a lista
x.sort(reverse=True)

# %%
x

# %% [markdown]
# # Fim

# %% [markdown]
# ## Dicionários

# %%
# Isso é uma lista
estudantes_lst = ["Mateus", 24, "Fernanda", 22, "Tamires", 26, "Cristiano", 25]

# %%
estudantes_lst

# %%
# Isso é um dicionário
estudantes_dict = {"Mateus":24, "Fernanda":22, "Tamires":26, "Cristiano":25}

# %%
estudantes_dict

# %%
type(estudantes_dict)

# %%
estudantes_dict["Fernanda"]
